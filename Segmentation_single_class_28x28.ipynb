# %% [markdown]
# ## All RBF Layers in one Class

# %%
import tensorflow as tf
import numpy as np
import gzip
import keras
import matplotlib.pyplot as plt
import time
import random
from sklearn.gaussian_process.kernels import PairwiseKernel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.gaussian_process import GaussianProcessRegressor
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam, Nadam

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=3)

# read data set
f = gzip.open('./data/train-images-idx3-ubyte.gz', 'rb')
x_train = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/train-labels-idx1-ubyte.gz', 'rb')
y_train = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

f = gzip.open('./data/t10k-images-idx3-ubyte.gz', 'rb')
x_test = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/t10k-labels-idx1-ubyte.gz', 'rb')
y_test = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

# data preprocessing
x_train = np.reshape(x_train, (-1, 784))
x_train = x_train / 255
x_train = x_train.astype(np.float32)
x_test = np.reshape(x_test, (-1, 784))
x_test = x_test / 255
x_test = x_test.astype(np.float32)

# get each training images
idx_train = [0 for i in range(10)]
idx_test = [0 for i in range(10)]
for i in range(10):
    idx_train[i] = (y_train == i)
    idx_test[i] = (y_test == i)
      
x_train_38 = x_train[idx_train[3]+idx_train[8]]
x_test_38 = x_test[idx_test[3]+idx_test[8]]

# x_temptr_38 = x_train[idx_train[3]+idx_train[8]][0:10000]
# x_tempte_38 = x_test[idx_test[3]+idx_test[8]][0:1500]

# y_train_38 = y_train[idx_train[3]+idx_train[8]][0:1000]
# print(np.count_nonzero(y_train_38[y_train_38==3]))

# one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

y_train_38 = y_train[idx_train[3]+idx_train[8]]
y_test_38 = y_test[idx_test[3]+idx_test[8]]

# y_temptr_38 = y_train[idx_train[3]+idx_train[8]][0:10000]
# y_tempte_38 = y_test[idx_test[3]+idx_test[8]][0:1500]

# %%
# K-Means clustering to find centers
_38 = []
for i in [3,8]:
    kmeans_model = KMeans(10)
    kmeans_model.fit(x_train[idx_train[i]])
    _38.extend(kmeans_model.cluster_centers_)

# %%
# plot cluster centers as images
fig = plt.figure(figsize = (10,10))

for i in range(20):
  subplot = fig.add_subplot(10, 10, i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.imshow(np.reshape(_38[i]*255, (28, 28)), cmap='gray')

# %%
# seg_num = 50

# center_7x7 =[]
# row_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]
# col_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]

# for i in range(seg_num):
#     for center in _38:
#         center_7x7.extend(center[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)] 
#                                 for r in range(row_7x7[i],row_7x7[i]+7))

# center_7x7 = np.reshape(center_7x7,(-1,7*7))
# print(center_7x7.shape)

# %%
# seg_num = 20
# center_14x14 =[]
# row_14x14 = [random.randrange(0,29-14) for _ in range(seg_num)]
# col_14x14 = [random.randrange(0,29-14) for _ in range(seg_num)]

# for i in range(seg_num):
#     for center in _38:
#         center_14x14.extend(center[r*28+col_14x14[i] : r*28+(col_14x14[i]+14)] 
#                                 for r in range(row_14x14[i],row_14x14[i]+14))

# center_14x14 = np.reshape(center_14x14,(-1,14*14))
# print(center_14x14.shape)
# Out:
# (400, 196)

# %%
seg_num = 20
center_14x14 =[]
row_14x14 = [random.randrange(0,29-28) for _ in range(seg_num)]
col_14x14 = [random.randrange(0,29-28) for _ in range(seg_num)]

for i in range(seg_num):
    for center in _38:
        center_14x14.extend(center[r*28+col_14x14[i] : r*28+(col_14x14[i]+28)] 
                                for r in range(row_14x14[i],row_14x14[i]+28))

center_14x14 = np.reshape(center_14x14,(-1,28*28))
print(center_14x14.shape)
# Out:
# (400, 784)

# %%
# center_28x28 = _38[:]
# center_28x28 = np.array(center_28x28)
# print(center_28x28.shape)

# %%
# x_7 = np.zeros((20,20))
# for i in range(20):
#     x_7[i][i] = 1

x_14 = np.zeros((20,20))
for i in range(20):
    x_14[i][i] = 1

# x_28 = np.zeros((20,20))
# for i in range(20):
#     x_28[i][i] = 1

# %%
# trimg_7x7 = []
# trlab_7x7 = []
# testimg_7x7 = []
# testlab_7x7 = []

# for i in range(seg_num):
    
#     for arr in x_train_38:
#         trimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)]
#                          for r in range(row_7x7[i],row_7x7[i]+7))
        
#     for arr in x_test_38:
#         testimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7) ] 
#                                   for r in range(row_7x7[i],row_7x7[i]+7))   
    
#     for arr in y_train_38:    
#         trlab_7x7.extend(arr)

#     for arr in y_test_38:    
#         testlab_7x7.extend(arr)

# trimg_7x7 = np.reshape(trimg_7x7,(-1,7*7))  
# testimg_7x7 = np.reshape(testimg_7x7,(-1,7*7))    
# trlab_7x7 = np.reshape(trlab_7x7,(-1,10))
# testlab_7x7 = np.reshape(testlab_7x7,(-1,10))

# print(trimg_7x7.shape)
# print(testimg_7x7.shape)

# %%
trimg_14x14 = []
trlab_14x14 = []
testimg_14x14 = []
testlab_14x14 = []

for i in range(seg_num):
    for arr in x_train_38:
        trimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+28) ] 
                                  for r in range(row_14x14[i],row_14x14[i]+28))
    for arr in x_test_38:
        testimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+28) ] 
                                  for r in range(row_14x14[i],row_14x14[i]+28))
    
    for arr in y_train_38:    
        trlab_14x14.extend(arr)

    for arr in y_test_38:    
        testlab_14x14.extend(arr)

trimg_14x14 = np.reshape(trimg_14x14,(-1,28*28))  
testimg_14x14 = np.reshape(testimg_14x14,(-1,28*28))    
trlab_14x14 = np.reshape(trlab_14x14,(-1,10))
testlab_14x14 = np.reshape(testlab_14x14,(-1,10))

print(trimg_14x14.shape)
print(testimg_14x14.shape)
# Out:
# (239640, 784)
# (39680, 784)

# %%
# trimg_28x28 = []
# trlab_28x28 = []
# testimg_28x28 = []
# testlab_28x28 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_28x28.extend(arr)
#     for arr in x_test_38:
#         testimg_28x28.extend(arr)
#     for arr in y_train_38:    
#         trlab_28x28.extend(arr)
#     for arr in y_test_38:    
#         testlab_28x28.extend(arr)

# trimg_28x28 = np.reshape(trimg_28x28,(-1,28*28))  
# testimg_28x28 = np.reshape(testimg_28x28,(-1,28*28))    
# trlab_28x28 = np.reshape(trlab_28x28,(-1,10))
# testlab_28x28 = np.reshape(testlab_28x28,(-1,10))

# print(trimg_28x28.shape)
# print(testimg_28x28.shape)

# %%
temp1 = []
temp2=[]
temp3=[]
temp4=[]

kernel = PairwiseKernel(metric='polynomial') 
rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14[0:20], x_14)

temp1= (rbf_models.predict(trimg_14x14[0:len(x_train_38)]))
temp2= (rbf_models.predict(testimg_14x14[0:len(x_test_38)]))
print(temp1.shape)

for i in range(1,seg_num):
    rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14[20*i:20*(i+1)], x_14)

    temp1= np.hstack([temp1,(rbf_models.predict(trimg_14x14[len(x_train_38)*i:len(x_train_38)*(i+1)]))])
    temp2= np.hstack([temp2,(rbf_models.predict(testimg_14x14[len(x_test_38)*i:len(x_test_38)*(i+1)]))])


# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14, x_14)

# temp3=(rbf_models.predict(trimg_14x14))
# temp4=(rbf_models.predict(testimg_14x14))

# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_28x28, x_28)

# temp5=(rbf_models.predict(trimg_28x28))
# temp6=(rbf_models.predict(testimg_28x28))


# temp1 = np.hstack([temp1,temp3])
# temp1 = np.hstack([temp1,temp5])

# temp2 = np.hstack([temp2,temp4])
# temp2 = np.hstack([temp2,temp6])

print(temp1.shape)
print(temp2.shape)

# trlab_7x7 = np.vstack([trlab_7x7,trlab_14x14])
# print(trlab_7x7.shape)
# Out:
# (11982, 20)
# (11982, 400)
# (1984, 400)

# %%
batch_size = 128
epochs = 100

model = Sequential()
model.add(Dense(10, activation='softmax', input_shape=(400,)))


model.summary()
nadam=keras.optimizers.Nadam(lr=0.0005)
model.compile(loss='categorical_crossentropy',optimizer=nadam,metrics=['accuracy'])

history = model.fit(temp1,y_train_38
                         ,batch_size=batch_size
                         ,epochs=epochs
                         ,verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                4010
# =================================================================
# Total params: 4,010
# Trainable params: 4,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 11982/11982 [==============================] - 0s 27us/step - loss: 1.7853 - acc: 0.5691
# Epoch 2/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.9733 - acc: 0.9181
# Epoch 3/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.6564 - acc: 0.9508
# Epoch 4/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.5035 - acc: 0.9568
# Epoch 5/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.4148 - acc: 0.9594
# Epoch 6/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.3569 - acc: 0.9605
# Epoch 7/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.3163 - acc: 0.9624
# Epoch 8/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.2864 - acc: 0.9631
# Epoch 9/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.2634 - acc: 0.9634
# Epoch 10/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2453 - acc: 0.9635
# Epoch 11/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2307 - acc: 0.9637
# Epoch 12/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2186 - acc: 0.9641
# Epoch 13/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2086 - acc: 0.9644
# Epoch 14/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2001 - acc: 0.9645
# Epoch 15/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1928 - acc: 0.9649
# Epoch 16/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1865 - acc: 0.9649
# Epoch 17/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1810 - acc: 0.9649
# Epoch 18/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1763 - acc: 0.9655
# Epoch 19/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1720 - acc: 0.9655
# Epoch 20/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1681 - acc: 0.9658
# Epoch 21/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1648 - acc: 0.9660
# Epoch 22/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1618 - acc: 0.9659
# Epoch 23/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1590 - acc: 0.9662
# Epoch 24/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1566 - acc: 0.9660
# Epoch 25/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1543 - acc: 0.9660
# Epoch 26/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1522 - acc: 0.9661
# Epoch 27/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1502 - acc: 0.9659
# Epoch 28/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1486 - acc: 0.9663
# Epoch 29/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1469 - acc: 0.9660
# Epoch 30/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1454 - acc: 0.9661
# Epoch 31/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1440 - acc: 0.9655
# Epoch 32/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1427 - acc: 0.9664
# Epoch 33/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1416 - acc: 0.9662
# Epoch 34/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1405 - acc: 0.9664
# Epoch 35/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1395 - acc: 0.9668
# Epoch 36/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.1385 - acc: 0.9664
# Epoch 37/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1376 - acc: 0.9662
# Epoch 38/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.1367 - acc: 0.9666
# Epoch 39/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1360 - acc: 0.9667
# Epoch 40/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.1352 - acc: 0.9665
# Epoch 41/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1345 - acc: 0.9664
# Epoch 42/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1340 - acc: 0.9659
# Epoch 43/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1332 - acc: 0.9670
# Epoch 44/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1328 - acc: 0.9666
# Epoch 45/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1321 - acc: 0.9666
# Epoch 46/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1317 - acc: 0.9664
# Epoch 47/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1310 - acc: 0.9665
# Epoch 48/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1306 - acc: 0.9666
# Epoch 49/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1301 - acc: 0.9663
# Epoch 50/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1297 - acc: 0.9660
# Epoch 51/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1293 - acc: 0.9671
# Epoch 52/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1289 - acc: 0.9666
# Epoch 53/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1285 - acc: 0.9669
# Epoch 54/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1282 - acc: 0.9668
# Epoch 55/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1279 - acc: 0.9670
# Epoch 56/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1275 - acc: 0.9667
# Epoch 57/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1273 - acc: 0.9666
# Epoch 58/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1268 - acc: 0.9672
# Epoch 59/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1265 - acc: 0.9671
# Epoch 60/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1263 - acc: 0.9670
# Epoch 61/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1260 - acc: 0.9668
# Epoch 62/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1258 - acc: 0.9671
# Epoch 63/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1255 - acc: 0.9672
# Epoch 64/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1253 - acc: 0.9668
# Epoch 65/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1251 - acc: 0.9670
# Epoch 66/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1249 - acc: 0.9675
# Epoch 67/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1247 - acc: 0.9675
# Epoch 68/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1245 - acc: 0.9670
# Epoch 69/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1245 - acc: 0.9671
# Epoch 70/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1242 - acc: 0.9671
# Epoch 71/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1241 - acc: 0.9673
# Epoch 72/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1238 - acc: 0.9670
# Epoch 73/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1237 - acc: 0.9668
# Epoch 74/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1235 - acc: 0.9670
# Epoch 75/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.1233 - acc: 0.9669
# Epoch 76/100
# 11982/11982 [==============================] - 0s 17us/step - loss: 0.1231 - acc: 0.9669
# Epoch 77/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1230 - acc: 0.9675
# Epoch 78/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1229 - acc: 0.9672
# Epoch 79/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1228 - acc: 0.9670
# Epoch 80/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.1226 - acc: 0.9671
# Epoch 81/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1226 - acc: 0.9669
# Epoch 82/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1225 - acc: 0.9667
# Epoch 83/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1223 - acc: 0.9672
# Epoch 84/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1223 - acc: 0.9671
# Epoch 85/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1221 - acc: 0.9672
# Epoch 86/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1221 - acc: 0.9672
# Epoch 87/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1219 - acc: 0.9670
# Epoch 88/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1219 - acc: 0.9673
# Epoch 89/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1217 - acc: 0.9672
# Epoch 90/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1217 - acc: 0.9670
# Epoch 91/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1217 - acc: 0.9670
# Epoch 92/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1217 - acc: 0.9674
# Epoch 93/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1214 - acc: 0.9665
# Epoch 94/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1214 - acc: 0.9671
# Epoch 95/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1214 - acc: 0.9670
# Epoch 96/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1212 - acc: 0.9673
# Epoch 97/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1212 - acc: 0.9675
# Epoch 98/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1211 - acc: 0.9673
# Epoch 99/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1212 - acc: 0.9669
# Epoch 100/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1209 - acc: 0.9673

# %%
score = model.evaluate(temp2,y_test_38, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.10882130362029609
# Test accuracy: 0.9702620967741935
