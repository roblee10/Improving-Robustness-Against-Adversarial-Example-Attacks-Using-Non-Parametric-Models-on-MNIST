# %% [markdown]
# ## All RBF Layers in one Class

# %%
import tensorflow as tf
import numpy as np
import gzip
import keras
import matplotlib.pyplot as plt
import time
import random
from sklearn.gaussian_process.kernels import PairwiseKernel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.gaussian_process import GaussianProcessRegressor
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam, Nadam
# Out:
# Using TensorFlow backend.

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=3)

# read data set
f = gzip.open('./data/train-images-idx3-ubyte.gz', 'rb')
x_train = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/train-labels-idx1-ubyte.gz', 'rb')
y_train = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

f = gzip.open('./data/t10k-images-idx3-ubyte.gz', 'rb')
x_test = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/t10k-labels-idx1-ubyte.gz', 'rb')
y_test = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

# data preprocessing
x_train = np.reshape(x_train, (-1, 784))
x_train = x_train / 255
x_train = x_train.astype(np.float32)
x_test = np.reshape(x_test, (-1, 784))
x_test = x_test / 255
x_test = x_test.astype(np.float32)

# get each training images
idx_train = [0 for i in range(10)]
idx_test = [0 for i in range(10)]
for i in range(10):
    idx_train[i] = (y_train == i)
    idx_test[i] = (y_test == i)
      
x_train_38 = x_train[idx_train[3]+idx_train[8]][0:1000]
x_test_38 = x_test[idx_test[3]+idx_test[8]][0:200]

# x_temptr_38 = x_train[idx_train[3]+idx_train[8]][0:10000]
# x_tempte_38 = x_test[idx_test[3]+idx_test[8]][0:1500]

# y_train_38 = y_train[idx_train[3]+idx_train[8]][0:1000]
# print(np.count_nonzero(y_train_38[y_train_38==3]))

# one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

y_train_38 = y_train[idx_train[3]+idx_train[8]][0:1000]
y_test_38 = y_test[idx_test[3]+idx_test[8]][0:200]

# y_temptr_38 = y_train[idx_train[3]+idx_train[8]][0:10000]
# y_tempte_38 = y_test[idx_test[3]+idx_test[8]][0:1500]

# %%
# K-Means clustering to find centers
_38 = []
for i in [3,8]:
    kmeans_model = KMeans(10)
    kmeans_model.fit(x_train[idx_train[i]])
    _38.extend(kmeans_model.cluster_centers_)

# %%
# plot cluster centers as images
fig = plt.figure(figsize = (10,10))

for i in range(20):
  subplot = fig.add_subplot(10, 10, i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.imshow(np.reshape(_38[i]*255, (28, 28)), cmap='gray')

# %%
# seg_num = 50

# center_7x7 =[]
# row_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]
# col_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]

# for i in range(seg_num):
#     for center in _38:
#         center_7x7.extend(center[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)] 
#                                 for r in range(row_7x7[i],row_7x7[i]+7))

# center_7x7 = np.reshape(center_7x7,(-1,7*7))
# print(center_7x7.shape)

# %%
seg_num = 50
center_14x14 =[]
row_14x14 = [random.randrange(0,29-14) for _ in range(seg_num)]
col_14x14 = [random.randrange(0,29-14) for _ in range(seg_num)]

for i in range(seg_num):
    for center in _38:
        center_14x14.extend(center[r*28+col_14x14[i] : r*28+(col_14x14[i]+14)] 
                                for r in range(row_14x14[i],row_14x14[i]+14))

center_14x14 = np.reshape(center_14x14,(-1,14*14))
print(center_14x14.shape)
# Out:
# (1000, 196)

# %%
# center_28x28 = _38[:]
# center_28x28 = np.array(center_28x28)
# print(center_28x28.shape)

# %%
# x_7 = np.zeros((20,20))
# for i in range(20):
#     x_7[i][i] = 1

x_14 = np.zeros((20,20))
for i in range(20):
    x_14[i][i] = 1

# x_28 = np.zeros((20,20))
# for i in range(20):
#     x_28[i][i] = 1

# %%
# trimg_7x7 = []
# trlab_7x7 = []
# testimg_7x7 = []
# testlab_7x7 = []

# for i in range(seg_num):
    
#     for arr in x_train_38:
#         trimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)]
#                          for r in range(row_7x7[i],row_7x7[i]+7))
        
#     for arr in x_test_38:
#         testimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7) ] 
#                                   for r in range(row_7x7[i],row_7x7[i]+7))   
    
#     for arr in y_train_38:    
#         trlab_7x7.extend(arr)

#     for arr in y_test_38:    
#         testlab_7x7.extend(arr)

# trimg_7x7 = np.reshape(trimg_7x7,(-1,7*7))  
# testimg_7x7 = np.reshape(testimg_7x7,(-1,7*7))    
# trlab_7x7 = np.reshape(trlab_7x7,(-1,10))
# testlab_7x7 = np.reshape(testlab_7x7,(-1,10))

# print(trimg_7x7.shape)
# print(testimg_7x7.shape)

# %%
trimg_14x14 = []
trlab_14x14 = []
testimg_14x14 = []
testlab_14x14 = []

for i in range(seg_num):
    for arr in x_train_38:
        trimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
                                  for r in range(row_14x14[i],row_14x14[i]+14))
    for arr in x_test_38:
        testimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
                                  for r in range(row_14x14[i],row_14x14[i]+14))
    
    for arr in y_train_38:    
        trlab_14x14.extend(arr)

    for arr in y_test_38:    
        testlab_14x14.extend(arr)

trimg_14x14 = np.reshape(trimg_14x14,(-1,14*14))  
testimg_14x14 = np.reshape(testimg_14x14,(-1,14*14))    
trlab_14x14 = np.reshape(trlab_14x14,(-1,10))
testlab_14x14 = np.reshape(testlab_14x14,(-1,10))

print(trimg_14x14.shape)
print(testimg_14x14.shape)
# Out:
# (50000, 196)
# (10000, 196)

# %%
# trimg_28x28 = []
# trlab_28x28 = []
# testimg_28x28 = []
# testlab_28x28 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_28x28.extend(arr)
#     for arr in x_test_38:
#         testimg_28x28.extend(arr)
#     for arr in y_train_38:    
#         trlab_28x28.extend(arr)
#     for arr in y_test_38:    
#         testlab_28x28.extend(arr)

# trimg_28x28 = np.reshape(trimg_28x28,(-1,28*28))  
# testimg_28x28 = np.reshape(testimg_28x28,(-1,28*28))    
# trlab_28x28 = np.reshape(trlab_28x28,(-1,10))
# testlab_28x28 = np.reshape(testlab_28x28,(-1,10))

# print(trimg_28x28.shape)
# print(testimg_28x28.shape)

# %%
temp1 = []
temp2=[]
temp3=[]
temp4=[]

kernel = PairwiseKernel(metric='polynomial') 
rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14[0:20], x_14)

temp1= (rbf_models.predict(trimg_14x14[0:1000]))
temp2= (rbf_models.predict(testimg_14x14[0:200]))
print(temp1.shape)

for i in range(1,seg_num):
    rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14[0:20], x_14)

    temp1= np.hstack([temp1,(rbf_models.predict(trimg_14x14[1000*i:1000*(i+1)]))])
    temp2= np.hstack([temp2,(rbf_models.predict(testimg_14x14[200*i:200*(i+1)]))])


# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14, x_14)

# temp3=(rbf_models.predict(trimg_14x14))
# temp4=(rbf_models.predict(testimg_14x14))

# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_28x28, x_28)

# temp5=(rbf_models.predict(trimg_28x28))
# temp6=(rbf_models.predict(testimg_28x28))


# temp1 = np.hstack([temp1,temp3])
# temp1 = np.hstack([temp1,temp5])

# temp2 = np.hstack([temp2,temp4])
# temp2 = np.hstack([temp2,temp6])

print(temp1.shape)
print(temp2.shape)

# trlab_7x7 = np.vstack([trlab_7x7,trlab_14x14])
# print(trlab_7x7.shape)
# Out:
# (1000, 20)
# (1000, 1000)
# (200, 1000)

# %%
batch_size = 128
epochs = 100

model = Sequential()
model.add(Dense(10, activation='softmax', input_shape=(1000,)))


model.summary()
nadam=keras.optimizers.Nadam(lr=0.0005)
model.compile(loss='categorical_crossentropy',optimizer=nadam,metrics=['accuracy'])

history = model.fit(temp1,trlab_14x14[0:1000]
                         ,batch_size=batch_size
                         ,epochs=epochs
                         ,verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 10,010
# Trainable params: 10,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1000/1000 [==============================] - 0s 140us/step - loss: 2.3669 - acc: 0.1820
# Epoch 2/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 2.0104 - acc: 0.3310
# Epoch 3/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 1.6923 - acc: 0.5120
# Epoch 4/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 1.4201 - acc: 0.6760
# Epoch 5/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 1.2021 - acc: 0.7760
# Epoch 6/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 1.0310 - acc: 0.8430
# Epoch 7/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.8963 - acc: 0.8870
# Epoch 8/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.7900 - acc: 0.9160
# Epoch 9/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.7050 - acc: 0.9300
# Epoch 10/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6368 - acc: 0.9410
# Epoch 11/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.5788 - acc: 0.9520
# Epoch 12/100
# 1000/1000 [==============================] - 0s 23us/step - loss: 0.5313 - acc: 0.9610
# Epoch 13/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.4910 - acc: 0.9670
# Epoch 14/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.4562 - acc: 0.9700
# Epoch 15/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.4260 - acc: 0.9750
# Epoch 16/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.4003 - acc: 0.9740
# Epoch 17/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.3771 - acc: 0.9740
# Epoch 18/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.3566 - acc: 0.9740
# Epoch 19/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.3385 - acc: 0.9740
# Epoch 20/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.3223 - acc: 0.9760
# Epoch 21/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.3074 - acc: 0.9770
# Epoch 22/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2941 - acc: 0.9770
# Epoch 23/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.2817 - acc: 0.9780
# Epoch 24/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.2708 - acc: 0.9810
# Epoch 25/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2605 - acc: 0.9790
# Epoch 26/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.2512 - acc: 0.9800
# Epoch 27/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2425 - acc: 0.9800
# Epoch 28/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2343 - acc: 0.9810
# Epoch 29/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.2269 - acc: 0.9800
# Epoch 30/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2200 - acc: 0.9800
# Epoch 31/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2133 - acc: 0.9820
# Epoch 32/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.2070 - acc: 0.9820
# Epoch 33/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.2014 - acc: 0.9830
# Epoch 34/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1959 - acc: 0.9830
# Epoch 35/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1910 - acc: 0.9840
# Epoch 36/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1861 - acc: 0.9830
# Epoch 37/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1814 - acc: 0.9840
# Epoch 38/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1771 - acc: 0.9820
# Epoch 39/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1730 - acc: 0.9850
# Epoch 40/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1690 - acc: 0.9850
# Epoch 41/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1654 - acc: 0.9850
# Epoch 42/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1619 - acc: 0.9850
# Epoch 43/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.1585 - acc: 0.9860
# Epoch 44/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1553 - acc: 0.9880
# Epoch 45/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1521 - acc: 0.9880
# Epoch 46/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1492 - acc: 0.9890
# Epoch 47/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1463 - acc: 0.9870
# Epoch 48/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1436 - acc: 0.9890
# Epoch 49/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1410 - acc: 0.9890
# Epoch 50/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1385 - acc: 0.9890
# Epoch 51/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1361 - acc: 0.9900
# Epoch 52/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1338 - acc: 0.9890
# Epoch 53/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.1314 - acc: 0.9900
# Epoch 54/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.1293 - acc: 0.9890
# Epoch 55/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1272 - acc: 0.9890
# Epoch 56/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1252 - acc: 0.9900
# Epoch 57/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1232 - acc: 0.9900
# Epoch 58/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1212 - acc: 0.9910
# Epoch 59/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1194 - acc: 0.9920
# Epoch 60/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1176 - acc: 0.9920
# Epoch 61/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1161 - acc: 0.9910
# Epoch 62/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1143 - acc: 0.9920
# Epoch 63/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1128 - acc: 0.9910
# Epoch 64/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1111 - acc: 0.9920
# Epoch 65/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1096 - acc: 0.9930
# Epoch 66/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1081 - acc: 0.9930
# Epoch 67/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1067 - acc: 0.9930
# Epoch 68/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1052 - acc: 0.9930
# Epoch 69/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1039 - acc: 0.9930
# Epoch 70/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1025 - acc: 0.9930
# Epoch 71/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1013 - acc: 0.9930
# Epoch 72/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1000 - acc: 0.9930
# Epoch 73/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0988 - acc: 0.9930
# Epoch 74/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0976 - acc: 0.9930
# Epoch 75/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0964 - acc: 0.9930
# Epoch 76/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0952 - acc: 0.9930
# Epoch 77/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0941 - acc: 0.9930
# Epoch 78/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0930 - acc: 0.9930
# Epoch 79/100
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0920 - acc: 0.9930
# Epoch 80/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0908 - acc: 0.9930
# Epoch 81/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0898 - acc: 0.9930
# Epoch 82/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0889 - acc: 0.9930
# Epoch 83/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0879 - acc: 0.9930
# Epoch 84/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0870 - acc: 0.9930
# Epoch 85/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0860 - acc: 0.9930
# Epoch 86/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0851 - acc: 0.9930
# Epoch 87/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0842 - acc: 0.9930
# Epoch 88/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0833 - acc: 0.9930
# Epoch 89/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0824 - acc: 0.9930
# Epoch 90/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0816 - acc: 0.9930
# Epoch 91/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0622 - acc: 0.992 - 0s 20us/step - loss: 0.0807 - acc: 0.9930
# Epoch 92/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0799 - acc: 0.9930
# Epoch 93/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0791 - acc: 0.9930
# Epoch 94/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0783 - acc: 0.9930
# Epoch 95/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0775 - acc: 0.9930
# Epoch 96/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.0768 - acc: 0.9930
# Epoch 97/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0760 - acc: 0.9930
# Epoch 98/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0753 - acc: 0.9930
# Epoch 99/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0746 - acc: 0.9930
# Epoch 100/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0739 - acc: 0.9930

# %%
score = model.evaluate(temp2, testlab_14x14[0:200], verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.17532778680324554
# Test accuracy: 0.955
