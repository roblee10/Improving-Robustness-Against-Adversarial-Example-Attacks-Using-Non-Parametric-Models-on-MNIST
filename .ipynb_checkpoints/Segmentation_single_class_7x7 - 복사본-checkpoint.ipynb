# %% [markdown]
# ## All RBF Layers in one Class

# %%
import tensorflow as tf
import numpy as np
import gzip
import keras
import matplotlib.pyplot as plt
import time
import random
from sklearn.gaussian_process.kernels import PairwiseKernel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.gaussian_process import GaussianProcessRegressor
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam, Nadam
# Out:
# Using TensorFlow backend.

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=3)

# read data set
f = gzip.open('./data/train-images-idx3-ubyte.gz', 'rb')
x_train = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/train-labels-idx1-ubyte.gz', 'rb')
y_train = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

f = gzip.open('./data/t10k-images-idx3-ubyte.gz', 'rb')
x_test = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/t10k-labels-idx1-ubyte.gz', 'rb')
y_test = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

# data preprocessing
x_train = np.reshape(x_train, (-1, 784))
x_train = x_train / 255
x_train = x_train.astype(np.float32)
x_test = np.reshape(x_test, (-1, 784))
x_test = x_test / 255
x_test = x_test.astype(np.float32)

# get each training images
idx_train = [0 for i in range(10)]
idx_test = [0 for i in range(10)]
for i in range(10):
    idx_train[i] = (y_train == i)
    idx_test[i] = (y_test == i)
      
x_train_38 = x_train[idx_train[3]+idx_train[8]]
x_test_38 = x_test[idx_test[3]+idx_test[8]]

# x_temptr_38 = x_train[idx_train[3]+idx_train[8]][0:10000]
# x_tempte_38 = x_test[idx_test[3]+idx_test[8]][0:1500]

# y_train_38 = y_train[idx_train[3]+idx_train[8]][0:1000]
# print(np.count_nonzero(y_train_38[y_train_38==3]))

# one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

y_train_38 = y_train[idx_train[3]+idx_train[8]]
y_test_38 = y_test[idx_test[3]+idx_test[8]]

# y_temptr_38 = y_train[idx_train[3]+idx_train[8]][0:10000]
# y_tempte_38 = y_test[idx_test[3]+idx_test[8]][0:1500]

# %%
# K-Means clustering to find centers
_38 = []
for i in [3,8]:
    kmeans_model = KMeans(10)
    kmeans_model.fit(x_train[idx_train[i]])
    _38.extend(kmeans_model.cluster_centers_)

# %%
# plot cluster centers as images
fig = plt.figure(figsize = (10,10))

for i in range(20):
  subplot = fig.add_subplot(10, 10, i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.imshow(np.reshape(_38[i]*255, (28, 28)), cmap='gray')

# %%
seg_num = 50

center_7x7 =[]
row_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]
col_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]

for i in range(seg_num):
    for center in _38:
        center_7x7.extend(center[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)] 
                                for r in range(row_7x7[i],row_7x7[i]+7))

center_7x7 = np.reshape(center_7x7,(-1,7*7))
print(center_7x7.shape)
# Out:
# (1000, 49)

# %%
# center_14x14 =[]
# row_14x14 = [random.randrange(0,29-14) for _ in range(10)]
# col_14x14 = [random.randrange(0,29-14) for _ in range(10)]

# for i in range(10):
#     for center in _38:
#         center_14x14.extend(center[r*28+col_14x14[i] : r*28+(col_14x14[i]+14)] 
#                                 for r in range(row_14x14[i],row_14x14[i]+14))

# center_14x14 = np.reshape(center_14x14,(-1,14*14))
# print(center_14x14.shape)

# %%
# center_28x28 = _38[:]
# center_28x28 = np.array(center_28x28)
# print(center_28x28.shape)

# %%
x_7 = np.zeros((20,20))
for i in range(20):
    x_7[i][i] = 1

# x_14 = np.zeros((200,200))
# for i in range(200):
#     x_14[i][i] = 1

# x_28 = np.zeros((20,20))
# for i in range(20):
#     x_28[i][i] = 1

# %%
trimg_7x7 = []
trlab_7x7 = []
testimg_7x7 = []
testlab_7x7 = []

for i in range(seg_num):
    
    for arr in x_train_38:
        trimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)]
                         for r in range(row_7x7[i],row_7x7[i]+7))
        
    for arr in x_test_38:
        testimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7) ] 
                                  for r in range(row_7x7[i],row_7x7[i]+7))   
    
    for arr in y_train_38:    
        trlab_7x7.extend(arr)

    for arr in y_test_38:    
        testlab_7x7.extend(arr)

trimg_7x7 = np.reshape(trimg_7x7,(-1,7*7))  
testimg_7x7 = np.reshape(testimg_7x7,(-1,7*7))    
trlab_7x7 = np.reshape(trlab_7x7,(-1,10))
testlab_7x7 = np.reshape(testlab_7x7,(-1,10))

print(trimg_7x7.shape)
print(testimg_7x7.shape)
# Out:
# (50000, 49)
# (10000, 49)

# %%
# trimg_14x14 = []
# trlab_14x14 = []
# testimg_14x14 = []
# testlab_14x14 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
#                                   for r in range(row_14x14[i],row_14x14[i]+14))
#     for arr in x_test_38:
#         testimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
#                                   for r in range(row_14x14[i],row_14x14[i]+14))
    
#     for arr in y_train_38:    
#         trlab_14x14.extend(arr)

#     for arr in y_test_38:    
#         testlab_14x14.extend(arr)

# trimg_14x14 = np.reshape(trimg_14x14,(-1,14*14))  
# testimg_14x14 = np.reshape(testimg_14x14,(-1,14*14))    
# trlab_14x14 = np.reshape(trlab_14x14,(-1,10))
# testlab_14x14 = np.reshape(testlab_14x14,(-1,10))

# print(trimg_14x14.shape)
# print(testimg_14x14.shape)

# %%
# trimg_28x28 = []
# trlab_28x28 = []
# testimg_28x28 = []
# testlab_28x28 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_28x28.extend(arr)
#     for arr in x_test_38:
#         testimg_28x28.extend(arr)
#     for arr in y_train_38:    
#         trlab_28x28.extend(arr)
#     for arr in y_test_38:    
#         testlab_28x28.extend(arr)

# trimg_28x28 = np.reshape(trimg_28x28,(-1,28*28))  
# testimg_28x28 = np.reshape(testimg_28x28,(-1,28*28))    
# trlab_28x28 = np.reshape(trlab_28x28,(-1,10))
# testlab_28x28 = np.reshape(testlab_28x28,(-1,10))

# print(trimg_28x28.shape)
# print(testimg_28x28.shape)

# %%
temp1 = []
temp2=[]
temp3=[]
temp4=[]

kernel = PairwiseKernel(metric='polynomial') 
rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_7x7[0:20], x_7)

temp1= (rbf_models.predict(trimg_7x7[0:1000]))
temp2= (rbf_models.predict(testimg_7x7[0:200]))
print(temp1.shape)

for i in range(1,seg_num):
    rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_7x7[0:20], x_7)

    temp1= np.hstack([temp1,(rbf_models.predict(trimg_7x7[1000*i:1000*(i+1)]))])
    temp2= np.hstack([temp2,(rbf_models.predict(testimg_7x7[200*i:200*(i+1)]))])


# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14, x_14)

# temp3=(rbf_models.predict(trimg_14x14))
# temp4=(rbf_models.predict(testimg_14x14))

# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_28x28, x_28)

# temp5=(rbf_models.predict(trimg_28x28))
# temp6=(rbf_models.predict(testimg_28x28))


# temp1 = np.hstack([temp1,temp3])
# temp1 = np.hstack([temp1,temp5])

# temp2 = np.hstack([temp2,temp4])
# temp2 = np.hstack([temp2,temp6])

print(temp1.shape)
print(temp2.shape)

# trlab_7x7 = np.vstack([trlab_7x7,trlab_14x14])
# print(trlab_7x7.shape)
# Out:
# (1000, 20)
# (1000, 1000)
# (200, 1000)

# %%
batch_size = 128
epochs = 100

model = Sequential()
model.add(Dense(10, activation='softmax', input_shape=(1000,)))


model.summary()
nadam=keras.optimizers.Nadam(lr=0.0005)
model.compile(loss='categorical_crossentropy',optimizer=nadam,metrics=['accuracy'])

history = model.fit(temp1,trlab_7x7[0:1000]
                         ,batch_size=batch_size
                         ,epochs=epochs
                         ,verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 10,010
# Trainable params: 10,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1000/1000 [==============================] - 2s 2ms/step - loss: 2.7005 - acc: 0.3520
# Epoch 2/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 1.7047 - acc: 0.5270
# Epoch 3/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 1.1476 - acc: 0.6250
# Epoch 4/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.7879 - acc: 0.7180
# Epoch 5/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5676 - acc: 0.7930
# Epoch 6/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.4329 - acc: 0.8320
# Epoch 7/100
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.3521 - acc: 0.8680
# Epoch 8/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2968 - acc: 0.8970
# Epoch 9/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.2588 - acc: 0.9090
# Epoch 10/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2298 - acc: 0.9200
# Epoch 11/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.2053 - acc: 0.9350
# Epoch 12/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1869 - acc: 0.9410
# Epoch 13/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1717 - acc: 0.9460
# Epoch 14/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1577 - acc: 0.9530
# Epoch 15/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1475 - acc: 0.9570
# Epoch 16/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.1378 - acc: 0.9570
# Epoch 17/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1298 - acc: 0.9650
# Epoch 18/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.1226 - acc: 0.9670
# Epoch 19/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.1159 - acc: 0.9670
# Epoch 20/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.1109 - acc: 0.9690
# Epoch 21/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.1060 - acc: 0.9750
# Epoch 22/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.1011 - acc: 0.9750
# Epoch 23/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0970 - acc: 0.9760
# Epoch 24/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0931 - acc: 0.9750
# Epoch 25/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0894 - acc: 0.9760
# Epoch 26/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0864 - acc: 0.9770
# Epoch 27/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0831 - acc: 0.9780
# Epoch 28/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0801 - acc: 0.9770
# Epoch 29/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0771 - acc: 0.9780
# Epoch 30/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0745 - acc: 0.9820
# Epoch 31/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0723 - acc: 0.9810
# Epoch 32/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0703 - acc: 0.9820
# Epoch 33/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0679 - acc: 0.9830
# Epoch 34/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0659 - acc: 0.9830
# Epoch 35/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0639 - acc: 0.9830
# Epoch 36/100
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.0620 - acc: 0.9830
# Epoch 37/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0601 - acc: 0.9860
# Epoch 38/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0584 - acc: 0.9870
# Epoch 39/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0568 - acc: 0.9850
# Epoch 40/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0553 - acc: 0.9880
# Epoch 41/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0537 - acc: 0.9870
# Epoch 42/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0523 - acc: 0.9880
# Epoch 43/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0514 - acc: 0.9890
# Epoch 44/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0499 - acc: 0.9880
# Epoch 45/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0487 - acc: 0.9880
# Epoch 46/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0477 - acc: 0.9880
# Epoch 47/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0464 - acc: 0.9910
# Epoch 48/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0455 - acc: 0.9930
# Epoch 49/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0446 - acc: 0.9930
# Epoch 50/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0435 - acc: 0.9930
# Epoch 51/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0425 - acc: 0.9950
# Epoch 52/100
# 1000/1000 [==============================] - 0s 16us/step - loss: 0.0419 - acc: 0.9950
# Epoch 53/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0408 - acc: 0.9950
# Epoch 54/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0400 - acc: 0.9960
# Epoch 55/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0392 - acc: 0.9950
# Epoch 56/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0386 - acc: 0.9960
# Epoch 57/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0379 - acc: 0.9950
# Epoch 58/100
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.0372 - acc: 0.9960
# Epoch 59/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0365 - acc: 0.9960
# Epoch 60/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0359 - acc: 0.9960
# Epoch 61/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0351 - acc: 0.9970
# Epoch 62/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0346 - acc: 0.9970
# Epoch 63/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0338 - acc: 0.9970
# Epoch 64/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0334 - acc: 0.9970
# Epoch 65/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0327 - acc: 0.9970
# Epoch 66/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0323 - acc: 0.9970
# Epoch 67/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0317 - acc: 0.9970
# Epoch 68/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0311 - acc: 0.9970
# Epoch 69/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0307 - acc: 0.9970
# Epoch 70/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0301 - acc: 0.9970
# Epoch 71/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0296 - acc: 0.9970
# Epoch 72/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0292 - acc: 0.9970
# Epoch 73/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0288 - acc: 0.9970
# Epoch 74/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0283 - acc: 0.9970
# Epoch 75/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0279 - acc: 0.9970
# Epoch 76/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0275 - acc: 0.9970
# Epoch 77/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0271 - acc: 0.9970
# Epoch 78/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0266 - acc: 0.9970
# Epoch 79/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0262 - acc: 0.9970
# Epoch 80/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0259 - acc: 0.9970
# Epoch 81/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0255 - acc: 0.9980
# Epoch 82/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0252 - acc: 0.9970
# Epoch 83/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0248 - acc: 0.9990
# Epoch 84/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0245 - acc: 1.000 - 0s 19us/step - loss: 0.0244 - acc: 0.9990
# Epoch 85/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0241 - acc: 0.9990
# Epoch 86/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0238 - acc: 0.9990
# Epoch 87/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0235 - acc: 0.9990
# Epoch 88/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0232 - acc: 0.9990
# Epoch 89/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0228 - acc: 0.9990
# Epoch 90/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0226 - acc: 0.9990
# Epoch 91/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0222 - acc: 0.9990
# Epoch 92/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0220 - acc: 0.9990
# Epoch 93/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0218 - acc: 0.9990
# Epoch 94/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0214 - acc: 1.0000
# Epoch 95/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0211 - acc: 1.0000
# Epoch 96/100
# 1000/1000 [==============================] - 0s 18us/step - loss: 0.0209 - acc: 1.0000
# Epoch 97/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0206 - acc: 1.0000
# Epoch 98/100
# 1000/1000 [==============================] - 0s 17us/step - loss: 0.0204 - acc: 1.0000
# Epoch 99/100
# 1000/1000 [==============================] - 0s 19us/step - loss: 0.0201 - acc: 1.0000
# Epoch 100/100
# 1000/1000 [==============================] - 0s 20us/step - loss: 0.0198 - acc: 1.0000

# %%
score = model.evaluate(temp2, testlab_7x7[0:len(, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.06402377046644687
# Test accuracy: 0.975
