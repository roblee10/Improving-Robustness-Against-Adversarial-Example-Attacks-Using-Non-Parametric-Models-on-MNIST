# %% [markdown]
# ## All RBF Layers in one Class

# %%
import tensorflow as tf
import numpy as np
import gzip
import keras
import matplotlib.pyplot as plt
import time
import random
from sklearn.gaussian_process.kernels import PairwiseKernel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.gaussian_process import GaussianProcessRegressor
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam, Nadam
# Out:
# Using TensorFlow backend.

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=3)

# read data set
f = gzip.open('./data/train-images-idx3-ubyte.gz', 'rb')
x_train = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/train-labels-idx1-ubyte.gz', 'rb')
y_train = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

f = gzip.open('./data/t10k-images-idx3-ubyte.gz', 'rb')
x_test = np.array(np.frombuffer(f.read(), np.uint8, offset=16))

f = gzip.open('./data/t10k-labels-idx1-ubyte.gz', 'rb')
y_test = np.array(np.frombuffer(f.read(), np.uint8, offset=8))

# data preprocessing
x_train = np.reshape(x_train, (-1, 784))
x_train = x_train / 255
x_train = x_train.astype(np.float32)
x_test = np.reshape(x_test, (-1, 784))
x_test = x_test / 255
x_test = x_test.astype(np.float32)

# get each training images
idx_train = [0 for i in range(10)]
idx_test = [0 for i in range(10)]
for i in range(10):
    idx_train[i] = (y_train == i)
    idx_test[i] = (y_test == i)
      
x_train_38 = x_train[idx_train[3]+idx_train[8]]
x_test_38 = x_test[idx_test[3]+idx_test[8]]

# x_temptr_38 = x_train[idx_train[3]+idx_train[8]][0:10000]
# x_tempte_38 = x_test[idx_test[3]+idx_test[8]][0:1500]

# y_train_38 = y_train[idx_train[3]+idx_train[8]][0:1000]
# print(np.count_nonzero(y_train_38[y_train_38==3]))

# one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

y_train_38 = y_train[idx_train[3]+idx_train[8]]
y_test_38 = y_test[idx_test[3]+idx_test[8]]

# %%
# K-Means clustering to find centers
_38 = []
for i in [3,8]:
    kmeans_model = KMeans(10)
    kmeans_model.fit(x_train[idx_train[i]])
    _38.extend(kmeans_model.cluster_centers_)

# %%
# plot cluster centers as images
fig = plt.figure(figsize = (10,10))

for i in range(20):
  subplot = fig.add_subplot(10, 10, i+1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.imshow(np.reshape(_38[i]*255, (28, 28)), cmap='gray')

# %%
seg_num = 20

center_7x7 =[]
row_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]
col_7x7 = [random.randrange(0,29-7) for _ in range(seg_num)]

for i in range(seg_num):
    for center in _38:
        center_7x7.extend(center[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)] 
                                for r in range(row_7x7[i],row_7x7[i]+7))

center_7x7 = np.reshape(center_7x7,(-1,7*7))
print(center_7x7.shape)
# Out:
# (400, 49)

# %%
# center_14x14 =[]
# row_14x14 = [random.randrange(0,29-14) for _ in range(10)]
# col_14x14 = [random.randrange(0,29-14) for _ in range(10)]

# for i in range(10):
#     for center in _38:
#         center_14x14.extend(center[r*28+col_14x14[i] : r*28+(col_14x14[i]+14)] 
#                                 for r in range(row_14x14[i],row_14x14[i]+14))

# center_14x14 = np.reshape(center_14x14,(-1,14*14))
# print(center_14x14.shape)

# %%
# center_28x28 = _38[:]
# center_28x28 = np.array(center_28x28)
# print(center_28x28.shape)

# %%
x_7 = np.zeros((20,20))
for i in range(20):
    x_7[i][i] = 1

# x_14 = np.zeros((200,200))
# for i in range(200):
#     x_14[i][i] = 1

# x_28 = np.zeros((20,20))
# for i in range(20):
#     x_28[i][i] = 1

# %%
trimg_7x7 = []
trlab_7x7 = []
testimg_7x7 = []
testlab_7x7 = []

for i in range(seg_num):
    
    for arr in x_train_38:
        trimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7)]
                         for r in range(row_7x7[i],row_7x7[i]+7))
        
    for arr in x_test_38:
        testimg_7x7.extend(arr[r*28+col_7x7[i] : r*28+(col_7x7[i]+7) ] 
                                  for r in range(row_7x7[i],row_7x7[i]+7))   
    
    for arr in y_train_38:    
        trlab_7x7.extend(arr)

    for arr in y_test_38:    
        testlab_7x7.extend(arr)

trimg_7x7 = np.reshape(trimg_7x7,(-1,7*7))  
testimg_7x7 = np.reshape(testimg_7x7,(-1,7*7))    
trlab_7x7 = np.reshape(trlab_7x7,(-1,10))
testlab_7x7 = np.reshape(testlab_7x7,(-1,10))

print(trimg_7x7.shape)
print(testimg_7x7.shape)
# Out:
# (239640, 49)
# (39680, 49)

# %%
# trimg_14x14 = []
# trlab_14x14 = []
# testimg_14x14 = []
# testlab_14x14 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
#                                   for r in range(row_14x14[i],row_14x14[i]+14))
#     for arr in x_test_38:
#         testimg_14x14.extend(arr[r*28+col_14x14[i] : r*28+(col_14x14[i]+14) ] 
#                                   for r in range(row_14x14[i],row_14x14[i]+14))
    
#     for arr in y_train_38:    
#         trlab_14x14.extend(arr)

#     for arr in y_test_38:    
#         testlab_14x14.extend(arr)

# trimg_14x14 = np.reshape(trimg_14x14,(-1,14*14))  
# testimg_14x14 = np.reshape(testimg_14x14,(-1,14*14))    
# trlab_14x14 = np.reshape(trlab_14x14,(-1,10))
# testlab_14x14 = np.reshape(testlab_14x14,(-1,10))

# print(trimg_14x14.shape)
# print(testimg_14x14.shape)

# %%
# trimg_28x28 = []
# trlab_28x28 = []
# testimg_28x28 = []
# testlab_28x28 = []

# for i in range(10):
#     for arr in x_train_38:
#         trimg_28x28.extend(arr)
#     for arr in x_test_38:
#         testimg_28x28.extend(arr)
#     for arr in y_train_38:    
#         trlab_28x28.extend(arr)
#     for arr in y_test_38:    
#         testlab_28x28.extend(arr)

# trimg_28x28 = np.reshape(trimg_28x28,(-1,28*28))  
# testimg_28x28 = np.reshape(testimg_28x28,(-1,28*28))    
# trlab_28x28 = np.reshape(trlab_28x28,(-1,10))
# testlab_28x28 = np.reshape(testlab_28x28,(-1,10))

# print(trimg_28x28.shape)
# print(testimg_28x28.shape)

# %%
temp1 = []
temp2=[]
temp3=[]
temp4=[]

kernel = PairwiseKernel(metric='polynomial') 
rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_7x7[0:20], x_7)

temp1= (rbf_models.predict(trimg_7x7[0:len(x_train_38)]))
temp2= (rbf_models.predict(testimg_7x7[0:len(x_test_38)]))
print(temp1.shape)

for i in range(1,seg_num):
    rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_7x7[20*i:20*(i+1)], x_7)

    temp1= np.hstack([temp1,(rbf_models.predict(trimg_7x7[len(x_train_38)*i:len(x_train_38)*(i+1)]))])
    temp2= np.hstack([temp2,(rbf_models.predict(testimg_7x7[len(x_test_38)*i:len(x_test_38)*(i+1)]))])


# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_14x14, x_14)

# temp3=(rbf_models.predict(trimg_14x14))
# temp4=(rbf_models.predict(testimg_14x14))

# rbf_models = GaussianProcessRegressor(kernel=kernel,alpha=0.1).fit(center_28x28, x_28)

# temp5=(rbf_models.predict(trimg_28x28))
# temp6=(rbf_models.predict(testimg_28x28))


# temp1 = np.hstack([temp1,temp3])
# temp1 = np.hstack([temp1,temp5])

# temp2 = np.hstack([temp2,temp4])
# temp2 = np.hstack([temp2,temp6])

print(temp1.shape)
print(temp2.shape)

# trlab_7x7 = np.vstack([trlab_7x7,trlab_14x14])
# print(trlab_7x7.shape)
# Out:
# (11982, 20)
# (11982, 400)
# (1984, 400)

# %%
batch_size = 128
epochs = 100

model = Sequential()
model.add(Dense(10, activation='softmax', input_shape=(400,)))


model.summary()
nadam=keras.optimizers.Nadam(lr=0.0005)
model.compile(loss='categorical_crossentropy',optimizer=nadam,metrics=['accuracy'])

history = model.fit(temp1,y_train_38
                         ,batch_size=batch_size
                         ,epochs=epochs
                         ,verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                4010
# =================================================================
# Total params: 4,010
# Trainable params: 4,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 11982/11982 [==============================] - 2s 144us/step - loss: 1.6813 - acc: 0.4595
# Epoch 2/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.5662 - acc: 0.8208
# Epoch 3/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.3475 - acc: 0.9095
# Epoch 4/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.2613 - acc: 0.9382
# Epoch 5/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.2140 - acc: 0.9509
# Epoch 6/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1832 - acc: 0.9579
# Epoch 7/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1613 - acc: 0.9630
# Epoch 8/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1451 - acc: 0.9666
# Epoch 9/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1323 - acc: 0.9700
# Epoch 10/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1220 - acc: 0.9722
# Epoch 11/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1136 - acc: 0.9746
# Epoch 12/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.1066 - acc: 0.9759
# Epoch 13/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.1004 - acc: 0.9775
# Epoch 14/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0953 - acc: 0.9775
# Epoch 15/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0907 - acc: 0.9790
# Epoch 16/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0868 - acc: 0.9794
# Epoch 17/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0833 - acc: 0.9801
# Epoch 18/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0800 - acc: 0.9812
# Epoch 19/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0771 - acc: 0.9807
# Epoch 20/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0745 - acc: 0.9811
# Epoch 21/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0723 - acc: 0.9821
# Epoch 22/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0700 - acc: 0.9821
# Epoch 23/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0682 - acc: 0.9829
# Epoch 24/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0663 - acc: 0.9828
# Epoch 25/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0644 - acc: 0.9835
# Epoch 26/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0629 - acc: 0.9836
# Epoch 27/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0613 - acc: 0.9842
# Epoch 28/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0601 - acc: 0.9847
# Epoch 29/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0588 - acc: 0.9843
# Epoch 30/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0576 - acc: 0.9849
# Epoch 31/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0564 - acc: 0.9858
# Epoch 32/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0553 - acc: 0.9859
# Epoch 33/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0543 - acc: 0.9861
# Epoch 34/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0534 - acc: 0.9858
# Epoch 35/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0526 - acc: 0.9864
# Epoch 36/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0515 - acc: 0.9871
# Epoch 37/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0507 - acc: 0.9868
# Epoch 38/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0498 - acc: 0.9872
# Epoch 39/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0492 - acc: 0.9875
# Epoch 40/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0484 - acc: 0.9876
# Epoch 41/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0477 - acc: 0.9871
# Epoch 42/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0470 - acc: 0.9874
# Epoch 43/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0465 - acc: 0.9876
# Epoch 44/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0458 - acc: 0.9879
# Epoch 45/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0453 - acc: 0.9878
# Epoch 46/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0447 - acc: 0.9883
# Epoch 47/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0440 - acc: 0.9885
# Epoch 48/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0435 - acc: 0.9883
# Epoch 49/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0430 - acc: 0.9885
# Epoch 50/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0425 - acc: 0.9887
# Epoch 51/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0421 - acc: 0.9891
# Epoch 52/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0416 - acc: 0.9887
# Epoch 53/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0411 - acc: 0.9891
# Epoch 54/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0406 - acc: 0.9891
# Epoch 55/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0404 - acc: 0.9886
# Epoch 56/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0400 - acc: 0.9893
# Epoch 57/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0397 - acc: 0.9890
# Epoch 58/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0392 - acc: 0.9890
# Epoch 59/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0387 - acc: 0.9896
# Epoch 60/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0384 - acc: 0.9892
# Epoch 61/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0381 - acc: 0.9895
# Epoch 62/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0376 - acc: 0.9899
# Epoch 63/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0373 - acc: 0.9893
# Epoch 64/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0371 - acc: 0.9893
# Epoch 65/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0368 - acc: 0.9899
# Epoch 66/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0365 - acc: 0.9898
# Epoch 67/100
# 11982/11982 [==============================] - 0s 17us/step - loss: 0.0360 - acc: 0.9897
# Epoch 68/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.0359 - acc: 0.9902
# Epoch 69/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0356 - acc: 0.9904
# Epoch 70/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0353 - acc: 0.9899
# Epoch 71/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0350 - acc: 0.9903
# Epoch 72/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0347 - acc: 0.9898
# Epoch 73/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0344 - acc: 0.9907
# Epoch 74/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0343 - acc: 0.9902
# Epoch 75/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0341 - acc: 0.9910
# Epoch 76/100
# 11982/11982 [==============================] - 0s 14us/step - loss: 0.0337 - acc: 0.9905
# Epoch 77/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0336 - acc: 0.9911
# Epoch 78/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0334 - acc: 0.9910
# Epoch 79/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0331 - acc: 0.9909
# Epoch 80/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0329 - acc: 0.9910
# Epoch 81/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0327 - acc: 0.9907
# Epoch 82/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0323 - acc: 0.9914
# Epoch 83/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0323 - acc: 0.9911
# Epoch 84/100
# 11982/11982 [==============================] - 0s 16us/step - loss: 0.0319 - acc: 0.9914
# Epoch 85/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0318 - acc: 0.9917
# Epoch 86/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0316 - acc: 0.9914
# Epoch 87/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0315 - acc: 0.9912
# Epoch 88/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0313 - acc: 0.9918
# Epoch 89/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0310 - acc: 0.9916
# Epoch 90/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0310 - acc: 0.9915
# Epoch 91/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0306 - acc: 0.9914
# Epoch 92/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0306 - acc: 0.9920
# Epoch 93/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0305 - acc: 0.9919
# Epoch 94/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0304 - acc: 0.9912
# Epoch 95/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0302 - acc: 0.9918
# Epoch 96/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0300 - acc: 0.9916
# Epoch 97/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0298 - acc: 0.9916
# Epoch 98/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0297 - acc: 0.9920
# Epoch 99/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0294 - acc: 0.9924
# Epoch 100/100
# 11982/11982 [==============================] - 0s 15us/step - loss: 0.0293 - acc: 0.9919

# %%
score = model.evaluate(temp2, y_test_38, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.033734535805236984
# Test accuracy: 0.9879032258064516
